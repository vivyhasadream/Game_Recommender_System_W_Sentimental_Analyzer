# %%
# standard packages for data analysis
import numpy as np
import pandas as pd
import pickle
import time

#visualization packages
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pickle.load(open('processed_df/steam_remsy.pkl','rb'))
df.head(3)
# Out:
#    appid                   name release_date developer publisher  \
# 0     10         Counter-Strike   2000-11-01     Valve     Valve
# 1     20  Team Fortress Classic   1999-04-01     Valve     Valve
# 2     30          Day of Defeat   2003-05-01     Valve     Valve
#
#    required_age  achievements  positive_ratings  negative_ratings  \
# 0             0             0            124534              3339
# 1             0             0              3318               633
# 2             0             0              3416               398
#
#    average_playtime  ...  Stats  Steam Achievements  Steam Cloud  \
# 0             17612  ...      0                   0            0
# 1               277  ...      0                   0            0
# 2               187  ...      0                   0            0
#
#    Steam Leaderboards  Steam Trading Cards  Steam Turn Notifications  \
# 0                   0                    0                         0
# ...

# %%
df2 = pickle.load(open('processed_df/preprocessed_nlp_5p.pkl','rb'))
df.head(3)
# Out:
#    appid                   name release_date developer publisher  \
# 0     10         Counter-Strike   2000-11-01     Valve     Valve
# 1     20  Team Fortress Classic   1999-04-01     Valve     Valve
# 2     30          Day of Defeat   2003-05-01     Valve     Valve
#
#    required_age  achievements  positive_ratings  negative_ratings  \
# 0             0             0            124534              3339
# 1             0             0              3318               633
# 2             0             0              3416               398
#
#    average_playtime  ...  Stats  Steam Achievements  Steam Cloud  \
# 0             17612  ...      0                   0            0
# 1               277  ...      0                   0            0
# 2               187  ...      0                   0            0
#
#    Steam Leaderboards  Steam Trading Cards  Steam Turn Notifications  \
# 0                   0                    0                         0
# ...
